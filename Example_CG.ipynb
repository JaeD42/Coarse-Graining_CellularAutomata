# %%
from Algorithm_Classes.CG_Class import *
from CA_Classes.CA1DClass import *
from CA_Classes.CA2DClass import *
from CA_Classes.ReversibleClass import *
from tqdm import tqdm

# %%
Automaton = ElementaryAutomaton(rule=59,size=4)

# %%
CG_Algorithm = Complete_Graph_Calc(Automaton)

# %%
CG_Algorithm.run()

# %%
CG_Algorithm.display_graph(max_iter=0)
# Out:
# <VertexPropertyMap object with value type 'int32_t', for Graph 0x7f6731ee3a58, at 0x7f6731ee3eb8>

# %%
CG_Algorithm.display_scc(max_iter=0)
